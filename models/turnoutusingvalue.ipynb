# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import (
    GroupKFold,
    GroupShuffleSplit,
    GridSearchCV
)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, ElasticNet
from sklearn.metrics import mean_absolute_error

import joblib

RND = 42

# %%
df_train = pd.read_csv("C:\\Users\\dipes\\Desktop\\election-analytics-nepal-2082\\data\\processed\\turnout_train_data.csv")

# %%
df_82 = pd.read_csv("C:\\Users\\dipes\\Desktop\\election-analytics-nepal-2082\\data\\processed\\turnout_prediction_base_2082.csv")

# %%
df_train.head()
# Out:
#    district_id  Absent rate within country 2078  Absent rate abroad 2078  \
# 0            1                             7.14                     5.17
# 1            2                             9.86                     6.79
# 2            3                             6.89                     6.74
# 3            4                             3.86                     9.15
# 4            5                            12.11                     5.00
#
#    Literacy Rate 2078  Primary Education % 2078  Lower Secondary % 2078  \
# 0               82.21                     30.53                   21.99
# 1               82.29                     28.29                   21.87
# 2               83.37                     27.97                   21.81
# 3               82.83                     25.65                   19.71
# 4               79.70                     33.99                   22.99
#
#    Upper Secondary % 2078  SLC or SEE % 2078  \
# 0                   19.39               9.24
# 1                   19.58              10.85
# 2                   19.62               9.34
# 3                   18.09              12.22
# 4                   16.17               8.64
#
#    Intermediate & equivalent % 2078  Graduate & equivalent % 2078  ...  \
# 0                              9.82                          2.58  ...
# 1                             10.29                          2.31  ...
# 2                             11.42                          3.16  ...
# 3                             12.89                          3.88  ...
# 4                              8.90                          2.29  ...
#
#    age_30-39_ratio  age_40-49_ratio  age_50-59_ratio  age_60-69_ratio  \
# 0         0.260930         0.179692         0.141929         0.113764
# 1         0.263347         0.174990         0.139309         0.120990
# 2         0.253653         0.198879         0.149377         0.120988
# 3         0.227545         0.220231         0.165927         0.113042
# 4         0.253139         0.188556         0.140592         0.116902
#
#    age_70+_ratio  female_ratio  registered_voters_lag  valid_pr_votes_lag  \
# 0       0.094767      0.466727                  78397               47056
# 1       0.115286      0.471929                 125219               68837
# 2       0.109776      0.484367                 204046              126160
# 3       0.114078      0.500910                 585166              385735
# 4       0.104288      0.482246                 105046               63344
#
#    registered_voters  valid_pr_votes
# 0              88285           46269
# 1             138932           71182
# 2             224877          123874
# 3             663311          416005
# 4             117554           62102
#
# [5 rows x 22 columns]

# %%
df_82.head()
# Out:
#    district_id  Absent rate within country 2078  Absent rate abroad 2078  \
# 0            1                             7.14                     5.17
# 1            2                             9.86                     6.79
# 2            3                             6.89                     6.74
# 3            4                             3.86                     9.15
# 4            5                            12.11                     5.00
#
#    Literacy Rate 2078  Primary Education % 2078  Lower Secondary % 2078  \
# 0               82.21                     30.53                   21.99
# 1               82.29                     28.29                   21.87
# 2               83.37                     27.97                   21.81
# 3               82.83                     25.65                   19.71
# 4               79.70                     33.99                   22.99
#
#    Upper Secondary % 2078  SLC or SEE % 2078  \
# 0                   19.39               9.24
# 1                   19.58              10.85
# 2                   19.62               9.34
# 3                   18.09              12.22
# 4                   16.17               8.64
#
#    Intermediate & equivalent % 2078  Graduate & equivalent % 2078  ...  \
# 0                              9.82                          2.58  ...
# 1                             10.29                          2.31  ...
# 2                             11.42                          3.16  ...
# 3                             12.89                          3.88  ...
# 4                              8.90                          2.29  ...
#
#    age_18-29_ratio  age_30-39_ratio  age_40-49_ratio  age_50-59_ratio  \
# 0         0.208919         0.260930         0.179692         0.141929
# 1         0.186077         0.263347         0.174990         0.139309
# 2         0.167327         0.253653         0.198879         0.149377
# 3         0.159176         0.227545         0.220231         0.165927
# 4         0.196523         0.253139         0.188556         0.140592
#
#    age_60-69_ratio  age_70+_ratio  female_ratio  registered_voters_lag  \
# 0         0.113764       0.094767      0.465442                  88285
# 1         0.120990       0.115286      0.469500                 138932
# 2         0.120988       0.109776      0.483838                 224877
# 3         0.113042       0.114078      0.497778                 663311
# 4         0.116902       0.104288      0.480298                 117554
#
#    valid_pr_votes_lag  registered_voters
# 0               46269              90327
# 1               71182             143408
# 2              123874             231809
# 3              416005             713537
# 4               62102             119630
#
# [5 rows x 21 columns]

# %%
TARGET = "valid_pr_votes"
GROUP = "district_id"

X = df_train.drop(columns=[TARGET, GROUP])
y = df_train[TARGET]
groups = df_train[GROUP]

# %%
gss = GroupShuffleSplit(
    n_splits=1,
    test_size=0.2,
    random_state=RND
)

train_idx, test_idx = next(gss.split(X, y, groups=groups))

X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
groups_train = groups.iloc[train_idx]

# %%
gkf = GroupKFold(n_splits=5)

# %%
ridge_pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("model", Ridge(random_state=RND))
])

# %%
enet_pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("model", ElasticNet(
        max_iter=10_000,
        random_state=RND
    ))
])

# %%
ridge_grid = {
    "model__alpha": np.logspace(-3, 3, 20)
}

enet_grid = {
    "model__alpha": np.logspace(-3, 2, 10),
    "model__l1_ratio": [0.1, 0.3, 0.5, 0.7, 0.9]
}

# %%
ridge_gs = GridSearchCV(
    ridge_pipe,
    ridge_grid,
    cv=gkf,
    scoring="neg_mean_absolute_error",
    n_jobs=-1
)

ridge_gs.fit(X_train, y_train, groups=groups_train)
# Out:
# GridSearchCV(cv=GroupKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('model', Ridge(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'model__alpha': array([1.00000000e-03, 2.06913808e-03, 4.28133240e-03, 8.85866790e-03,
#        1.83298071e-02, 3.79269019e-02, 7.84759970e-02, 1.62377674e-01,
#        3.35981829e-01, 6.95192796e-01, 1.43844989e+00, 2.97635144e+00,
#        6.15848211e+00, 1.27427499e+01, 2.63665090e+01, 5.45559478e+01,
#        1.12883789e+02, 2.33572147e+02, 4.83293024e+02, 1.00000000e+03])},
#              scoring='neg_mean_absolute_error')

# %%
enet_gs = GridSearchCV(
    enet_pipe,
    enet_grid,
    cv=gkf,
    scoring="neg_mean_absolute_error",
    n_jobs=-1
)

enet_gs.fit(X_train, y_train, groups=groups_train)
# Out:
# GridSearchCV(cv=GroupKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('model',
#                                         ElasticNet(max_iter=10000,
#                                                    random_state=42))]),
#              n_jobs=-1,
#              param_grid={'model__alpha': array([1.00000000e-03, 3.59381366e-03, 1.29154967e-02, 4.64158883e-02,
#        1.66810054e-01, 5.99484250e-01, 2.15443469e+00, 7.74263683e+00,
#        2.78255940e+01, 1.00000000e+02]),
#                          'model__l1_ratio': [0.1, 0.3, 0.5, 0.7, 0.9]},
#              scoring='neg_mean_absolute_error')

# %%
ridge_pred = ridge_gs.best_estimator_.predict(X_test)
enet_pred = enet_gs.best_estimator_.predict(X_test)

ridge_mae = mean_absolute_error(y_test, ridge_pred)
enet_mae = mean_absolute_error(y_test, enet_pred)

print(f"Ridge MAE (district holdout): {ridge_mae:.2f}")
print(f"ElasticNet MAE (district holdout): {enet_mae:.2f}")
# Out:
# Ridge MAE (district holdout): 4763.69
# ElasticNet MAE (district holdout): 7861.64

# %%
if ridge_mae <= enet_mae:
    final_model = ridge_gs.best_estimator_
    model_name = "ridge"
else:
    final_model = enet_gs.best_estimator_
    model_name = "elasticnet"

print(f"Selected model: {model_name}")
# Out:
# Selected model: ridge

# %%
final_model.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model', Ridge(alpha=np.float64(0.001), random_state=42))])

# %%
artifact_path = f"artifacts/vote_turnout_model_{model_name}.joblib"
joblib.dump(final_model, artifact_path)

print(f"Model saved to: {artifact_path}")
# Out:
# Model saved to: artifacts/vote_turnout_model_ridge.joblib

# %%
df_82["predicted_valid_pr_votes"] = final_model.predict(df_82.drop(columns=[GROUP]))

# %%
df_train.head(20)
# Out:
#     district_id  Absent rate within country 2078  Absent rate abroad 2078  \
# 0             1                             7.14                     5.17
# 1             2                             9.86                     6.79
# 2             3                             6.89                     6.74
# 3             4                             3.86                     9.15
# 4             5                            12.11                     5.00
# 5             6                            10.16                     6.51
# 6             7                            15.12                     5.77
# 7             8                            12.58                     6.37
# 8             9                             3.79                     6.61
# 9            10                             3.08                     6.70
# 10           11                            15.36                     4.72
# 11           12                            17.81                     6.39
# 12           13                            23.16                     5.34
# 13           14                            12.12                     6.17
# 14           15                             3.33                     4.74
# 15           16                             2.06                     7.63
# 16           17                            27.49                     5.27
# 17           18                            49.33                     5.79
# 18           19                            18.89                     4.58
# 19           20                             2.66                     8.49
#
#     Literacy Rate 2078  Primary Education % 2078  Lower Secondary % 2078  \
# 0                82.21                     30.53                   21.99
# 1                82.29                     28.29                   21.87
# 2                83.37                     27.97                   21.81
# 3                82.83                     25.65                   19.71
# 4                79.70                     33.99                   22.99
# 5                81.94                     27.00                   20.59
# 6                78.87                     32.51                   22.23
# 7                81.36                     28.56                   21.65
# 8                78.61                     26.96                   19.12
# 9                78.10                     27.98                   18.84
# 10               76.95                     34.28                   20.40
# 11               75.99                     31.10                   20.54
# 12               73.89                     31.98                   20.14
# 13               77.17                     30.84                   21.32
# 14               67.69                     29.45                   19.87
# 15               65.11                     30.38                   19.88
# 16               72.31                     31.51                   20.27
# 17               68.12                     32.45                   20.72
# 18               72.59                     33.08                   20.66
# 19               65.22                     30.26                   20.78
#
#     Upper Secondary % 2078  SLC or SEE % 2078  \
# 0                    19.39               9.24
# 1                    19.58              10.85
# 2                    19.62               9.34
# 3                    18.09              12.22
# 4                    16.17               8.64
# 5                    20.14              12.24
# 6                    18.71               9.79
# 7                    18.84              10.61
# 8                    16.83              12.43
# 9                    16.83              12.22
# 10                   14.20               7.05
# 11                   20.50               9.49
# 12                   16.57               7.72
# 13                   16.80              10.51
# 14                   17.98              10.08
# 15                   17.67               8.99
# 16                   13.95               8.91
# 17                   15.97               8.09
# 18                   15.19               9.26
# 19                   17.27               8.21
#
#     Intermediate & equivalent % 2078  Graduate & equivalent % 2078  ...  \
# 0                               9.82                          2.58  ...
# 1                              10.29                          2.31  ...
# 2                              11.42                          3.16  ...
# 3                              12.89                          3.88  ...
# 4                               8.90                          2.29  ...
# 5                              10.57                          2.96  ...
# 6                               7.73                          1.87  ...
# 7                              10.25                          2.74  ...
# 8                              12.81                          4.30  ...
# 9                              12.58                          3.72  ...
# 10                             12.22                          2.86  ...
# 11                             10.00                          2.20  ...
# 12                             12.63                          2.68  ...
# 13                             10.50                          2.49  ...
# 14                             10.79                          4.17  ...
# 15                              9.96                          3.42  ...
# 16                             12.36                          2.99  ...
# 17                             11.31                          2.28  ...
# 18                             11.53                          2.24  ...
# 19                             10.30                          4.04  ...
#
#     age_30-39_ratio  age_40-49_ratio  age_50-59_ratio  age_60-69_ratio  \
# 0          0.260930         0.179692         0.141929         0.113764
# 1          0.263347         0.174990         0.139309         0.120990
# 2          0.253653         0.198879         0.149377         0.120988
# 3          0.227545         0.220231         0.165927         0.113042
# 4          0.253139         0.188556         0.140592         0.116902
# 5          0.255917         0.179020         0.145768         0.120924
# 6          0.244724         0.176216         0.154048         0.130798
# 7          0.246308         0.191556         0.157593         0.123243
# 8          0.231441         0.214057         0.163345         0.119722
# 9          0.241735         0.215905         0.167618         0.112844
# 10         0.245852         0.180097         0.146933         0.118763
# 11         0.250639         0.165667         0.143917         0.122111
# 12         0.248788         0.179057         0.150022         0.114656
# 13         0.249877         0.190038         0.150888         0.107033
# 14         0.230044         0.206964         0.164688         0.104840
# 15         0.229999         0.206820         0.160394         0.106590
# 16         0.252118         0.188280         0.150815         0.117543
# 17         0.250330         0.174811         0.150326         0.111481
# 18         0.259177         0.190402         0.154563         0.108432
# 19         0.231882         0.200583         0.163153         0.117280
#
#     age_70+_ratio  female_ratio  registered_voters_lag  valid_pr_votes_lag  \
# 0        0.094767      0.466727                  78397               47056
# 1        0.115286      0.471929                 125219               68837
# 2        0.109776      0.484367                 204046              126160
# 3        0.114078      0.500910                 585166              385735
# 4        0.104288      0.482246                 105046               63344
# 5        0.094822      0.488496                  66667               41255
# 6        0.133542      0.480252                 113745               56893
# 7        0.106354      0.499568                 105188               63112
# 8        0.115782      0.491068                 644782              417601
# 9        0.104719      0.495896                 474831              292993
# 10       0.125639      0.483043                  69411               36771
# 11       0.134265      0.475272                 125108               63395
# 12       0.114697      0.492642                 102250               59892
# 13       0.106179      0.492907                 193918              104319
# 14       0.125076      0.480601                 346200              191917
# 15       0.120638      0.469849                 344370              212313
# 16       0.123608      0.494487                 147923               79145
# 17       0.110725      0.488807                 152559               78677
# 18       0.102107      0.484520                 181518              104470
# 19       0.136714      0.467069                 404675              241440
#
#     registered_voters  valid_pr_votes
# 0               88285           46269
# 1              138932           71182
# 2              224877          123874
# 3              663311          416005
# 4              117554           62102
# 5               71933           40657
# 6              123379           58743
# 7              116991           66320
# 8              735525          458853
# 9              544941          327498
# 10              81502           38317
# 11             142792           64369
# 12             117897           62659
# 13             228946          114903
# 14             418374          264270
# 15             422712          267819
# 16             161450           81332
# 17             180106           84816
# 18             208369          113529
# 19             474587          298311
#
# [20 rows x 22 columns]

# %%
df_82["predicted_rate"] = df_82["predicted_valid_pr_votes"] / df_82["registered_voters"] * 100

# %%
df_82["predicted_valid_pr_votes"].sum()
# Out:
# np.float64(10404605.122769851)
